# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Отлично, Кирилл! Ты здорово поработал над комментариями и теперь твой проект принят.
#
# Спасибо за работу и успехов в следующих проектах!)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Привет!</b>
#
# Меня зовут Михаленко Дмитрий, и я буду проверять твой проект. Предлагаю общаться на «ты» :) Но если это не удобно - дай знать, и мы перейдем на "вы".
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных. Ты уже проделал большую работу над проектом, но давай сделаем его еще лучше. Ниже ты найдешь мои комментарии - **пожалуйста, не перемещай, не изменяй и не удаляй их**. Увидев у тебя ошибку, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой начальник будет поступать так же, а я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Так выделены небольшие замечания. Я надеюсь, что их ты тоже учтешь - твой проект от этого станет только лучше. Но настаивать на их отработке не буду.
#
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом.** Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Все же перед началом любого исследования должна хотя бы коротко обозначаться его основная цель)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Добавил необходимую информацию в начале проекта.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Молодец! Теперь все как надо

# %% [markdown]
# ### Описание проекта
# #### Общая информация и постановка задач
# Перед нами данные о пользователя, привлечённых с 1 мая по 27 октября 2019 года, покупок и затрат на маркетинг развлекательного приложения Procrastinate Pro+.
#
# **Проблема:** Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки.
#
# **Задача:** Разобраться в причинах и помочь компании выйти в плюс.
#
# Нам предстоит изучить:
# - откуда приходят пользователи и какими устройствами они пользуются,
# - сколько стоит привлечение пользователей из различных рекламных каналов;
# - сколько денег приносит каждый клиент,
# - когда расходы на привлечение клиента окупаются,
# - какие факторы мешают привлечению клиентов.
#
# #### Описание данных
#
# В вашем распоряжении три датасета:
#  - Файл _visits_info_short.csv_ хранит лог сервера с информацией о посещениях сайта
#  - Файл _orders_info_short.csv_ — информацию о заказах
#  - Файл _costs_info_short.csv_ — информацию о расходах на рекламу.
#
# Структура _visits_info_short.csv_:
# - User Id — уникальный идентификатор пользователя,
# - Region — страна пользователя,
# - Device — тип устройства пользователя,
# - Channel — идентификатор источника перехода,
# - Session Start — дата и время начала сессии,
# - Session End — дата и время окончания сессии.
#
# Структура _orders_info_short.csv_:
# - User Id — уникальный идентификатор пользователя,
# - Event Dt — дата и время покупки,
# - Revenue — сумма заказа.
#
# Структура _costs_info_short.csv_:
# - dt — дата проведения рекламной кампании,
# - Channel — идентификатор рекламного источника,
# - costs — расходы на эту кампанию.

# %% [markdown]
# ### Загрузите данные и подготовьте их к анализу

# %% [markdown]
# Загрузите данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
#
# **Пути к файлам**
#
# - визиты: `/datasets/visits_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/visits_info_short.csv);
# - заказы: `/datasets/orders_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/orders_info_short.csv);
# - расходы: `/datasets/costs_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/costs_info_short.csv).
#
# Изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем.

# %%
# импортируем необходимые библиотеки
import pandas as pd
import numpy as np
from datetime import timedelta, datetime
import seaborn as sns
from matplotlib import pyplot as plt

# выгрузим датафреймы и присвоим их соответствующим переменным
visits = pd.read_csv('/datasets/visits_info_short.csv')
orders = pd.read_csv('/datasets/orders_info_short.csv')
costs = pd.read_csv('/datasets/costs_info_short.csv')

# %% [markdown]
# Выведем общую информацию по полученным датафреймам:

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Видим наличие некорректных типов значений в столбцах с датами и отсутствие змеинного регистра в названиях столбцов. Для начала приведем названия столбцов к общему регистру, после чего изменим тип данных в соответстующих столбцах:

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Хорошо замечено </div>

# %%
visits.columns=['user_id','region','device','channel','session_start','session_end']
orders.columns=['user_id','event_dt','revenue']
costs.columns=['dt','channel','costs']

visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %%
visits.info()
orders.info()
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
# ...

# %% [markdown]
# Привели названия столбцов к единому формату, значения дат к корректному типу.
# Проверим наличие дубликатов в данных:

# %%
print(f'Количество явных дубликатов в таблице visits: {visits.duplicated().sum()}')
print(f'Количество явных дубликатов в таблице orders: {orders.duplicated().sum()}')
print(f'Количество явных дубликатов в таблице costs: {costs.duplicated().sum()}')
# Out:
# Количество явных дубликатов в таблице visits: 0
# Количество явных дубликатов в таблице orders: 0
# Количество явных дубликатов в таблице costs: 0

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Явные дубликаты также не пропущены</div>

# %% [markdown]
# Явных дубликатов в таблицах не оказалось. Проверим наличие дубликатов в столбцах таблиц:

# %%
visits.channel.unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %%
visits.region.unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %%
visits.device.unique()
# Out:
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)

# %%
costs.channel.unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %% [markdown]
# Неявные дубликаты в столбцах отсутствуют.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Отлично, даты переведены в нужный формат, проверены дубликаты и пропуски, использован snake_case </div>

# %% [markdown]
# ### Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %% [markdown]
# Создадим функцию get_profiles() для создания профилей пользователей:

# %%
def get_profiles(visits, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        visits.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# Создадим функцию get_retention() для подсчёта Retention Rate:

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Создадим функцию get_conversion() для подсчёта конверсии:

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Создадим функцию get_ltv() для подсчёта LTV:

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# Создадим функцию filter_data() для сглаживания данных:

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# Создадим функцию plot_retention() для построения графика Retention Rate,

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Создадим функцию plot_conversion() для построения графика конверсии,

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Создадим функцию plot_ltv_roi для визуализации LTV и ROI.

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Необходимые функции загружены </div>

# %% [markdown]
# ### Исследовательский анализ данных
#
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
# После каждого пункта сформулируйте выводы.

# %% [markdown]
# #### Профили пользователей

# %% [markdown]
# Определим максимальну и минимальную даты привлечения пользователей:

# %%
profiles = get_profiles(visits, orders, costs)


min_date = profiles['dt'].min()
max_date = profiles['dt'].max()
print(f'Минимальная дата привлечения пользователей: {min_date}')
print(f'Максимальная дата привлечения пользователей: {max_date}')
# Out:
# Минимальная дата привлечения пользователей: 2019-05-01
# Максимальная дата привлечения пользователей: 2019-10-27

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Минимальная и максимальная даты есть </div>

# %%
profiles = get_profiles(visits, orders, costs)
# проверим работу функции
profiles
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %% [markdown]
# Функция работает корректно.

# %% [markdown]
# #### Доля платящих клиентов в разбивке по странам
#
# Создадим функцию get_share(), принимающую на вход таблицу с данными и параметр для группировки:

# %%
def get_share(profiles, parameter):
    # сгруппируем профили по параметру и посчитаем количество уникальных пользователей
    grouped_users = (profiles.groupby(parameter).agg({'user_id':'nunique'}))
    
    # также сгруппируем платящих пользователей по регионам и посчитаем количество уникальных значений
    grouped_paying_users = (profiles
                            .query('payer == True')
                            .groupby(parameter).agg({'user_id':'nunique'})
                           )
    # объединим таблицы
    grouped_users = grouped_users.merge(grouped_paying_users, on=parameter, how='left')
    grouped_users.columns = ('n_users', 'n_paying_users')
    
    # вычислим процент платящих клиентов в для каждой страны
    grouped_users['perc_paying_users'] = grouped_users['n_paying_users'] / grouped_users['n_users'] * 100
    
    return grouped_users[['n_users','perc_paying_users']].sort_values(by='perc_paying_users', ascending=False)

# %% [markdown]
# Применим функцию для вывода таблицы доля платящих клиентов в разбивке по регионам:

# %%
get_share(profiles, 'region')
# Out:
#                n_users  perc_paying_users
# region
# United States   100002           6.901862
# Germany          14981           4.111875
# UK               17575           3.982930
# France           17450           3.799427

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Правильно считаешь доли платящих в каждом сегменте </div>

# %% [markdown]
# **Основные выводы:**
# - Количество пользователей в США в разы больше того же показателя для других стран, где закономерно наибольший процент платящих пользователей среди всех привлеченных. Видимо в основном приложение ориентировано на Соединенные Штаты.
# - Германия по доле платящих пользователей расположилась на 2-ом месте, хотя имеет наименьший показатель привлеченных пользователей.
# - На последнем месте по доле платящих клиентов расположилась Франция, хотя по количеству привлеченных пользователей находится не на последнем месте.

# %% [markdown]
# #### Доля платящих клиентов в разбивке по устройствам
#
# Применим ранее написанную функцию для вывода таблицы доли платящих клиентов в разбивке по устройствам:

# %%
get_share(profiles, 'device')
# Out:
#          n_users  perc_paying_users
# device
# Mac        30042           6.364423
# iPhone     54479           6.207897
# Android    35032           5.851793
# PC         30455           5.046790

# %% [markdown]
# **Основные выводы:**
# - Наибольший процент платящих клиентов среди владельцев Mac, при том что данных пользователей меньше всего.
# - Для владельцев Iphone доля платящих клиентов в процентном соотношении находится на втором месте, однако количество зарегистрированных клиентов на этом устройстве почти в 2 раза превышает количество пользователей на других платформах. Возможно, что в части яблочных устройств механизмы оплаты на стационарных устройствах реализованы лучше, чем на мобильных, но это уже технические вопросы.
# - Минимальная доля платящих клиентов среди пользователей PC при практически минимальном общем количестве пользователей данных девайсов.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Здесь также всё отлично, техника Apple в явных лидерах </div>

# %% [markdown]
# #### Доля платящих клиентов в разбивке по каналам привлечения
#
# Применим функцию для нахождения доли платящих клиентов в разрезе каналов привлечения:

# %%
get_share(profiles, 'channel')
# Out:
#                     n_users  perc_paying_users
# channel
# FaceBoom              29144          12.204914
# AdNonSense             3880          11.340206
# lambdaMediaAds         2149          10.469986
# TipTop                19561           9.600736
# RocketSuperAds         4448           7.913669
# WahooNetBanner         8553           5.296387
# YRabbit                4312           3.826531
# MediaTornado           4364           3.574702
# LeapBob                8553           3.063253
# OppleCreativeMedia     8605           2.707728
# organic               56439           2.055316

# %% [markdown]
# **Основные выводы**:
# - Наибольшее количество пользователей пришли самостоятельно, но и доля платящих клиентов среди них минимальна, чего и следовало ожидать.
# - Наибольший приток платящих клиентов показывает канал FaceBoom, количество пришедших пользователей по этом каналу на 2-ом месте по величине.
# - Стоит обратить внимание на каналы привлечения AdNonSense и lambdaMediaAds: при минимальных показателях привлечения пользователей они имеют большую долю платящих среди всех привлеченных.
# - Канал TipTop, хоть и привлек почти 13% пользователей, не отличился высокой долей платящих среди них.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> И снова по расчетам доли все безупречно, хороший промежуточный вывод </div>

# %% [markdown]
# ### Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %% [markdown]
# #### Общие траты на маркетинг

# %%
# выведем общую сумму трат на маркетинг
total_costs = costs['costs'].sum()
print(total_costs)
# Out:
# 105497.30000000002

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Общая сумма определена </div>

# %% [markdown]
# #### Общие траты на маркетинг в разбивке по каналам привлечения

# %%
# выведем суммы общих расходов на рекламу по каналам привлечения
total_costs_by_channel = (costs.groupby('channel')
                               .agg({'costs':'sum'})
                               .merge(get_share(profiles, 'channel'), on='channel', how='left')
                               .sort_values(by='costs', ascending=False))
total_costs_by_channel
# Out:
#                        costs  n_users  perc_paying_users
# channel
# TipTop              54751.30    19561           9.600736
# FaceBoom            32445.60    29144          12.204914
# WahooNetBanner       5151.00     8553           5.296387
# AdNonSense           3911.25     3880          11.340206
# OppleCreativeMedia   2151.25     8605           2.707728
# RocketSuperAds       1833.00     4448           7.913669
# LeapBob              1797.60     8553           3.063253
# lambdaMediaAds       1557.60     2149          10.469986
# MediaTornado          954.48     4364           3.574702
# YRabbit               944.22     4312           3.826531

# %% [markdown]
# **Основные выводы:**
# - Видим наибольшие расходы на привлечение пользователей в каналы TipTop (при этом процент платящих пользователей среди привлеченных только на 4-ом месте) и FaceBoom (первое место по количеству платящих пользователей).
# - Наименьшие траты по каналам MediaTornado и YRabbit.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> И суммы по всем каналам также рассчитаны корректно, хорошо </div>

# %% [markdown]
# #### Динамика изменения расходов во времени
#
# Построим визаулизацию динамики изменения расходов во времени по каналам привлечения:

# %%
costs['week'] = pd.to_datetime(costs['dt']).dt.isocalendar().week
costs['month'] = pd.to_datetime(costs['dt']).dt.month

costs_month = costs.pivot_table(index='month', columns='channel', values='costs', aggfunc='sum')
costs_week = costs.pivot_table(index='week', columns='channel', values='costs', aggfunc='sum')

plt.figure(figsize=(20,6))

ax1 = costs_week.plot(
    grid=True,
    ax=plt.subplot(1,2,1)
)

plt.title(f'Динамика изменения расходов по неделям')
plt.xlabel('Неделя привлечения')
plt.ylabel('Расходы на маркетинг')

costs_month.plot(
    grid=True,
    ax=plt.subplot(1,2,2, sharey=ax1)
)

plt.title(f'Динамика изменения расходов по месяцам')
plt.xlabel('Месяц привлечения')
plt.show()

# %% [markdown]
# **Основные выводы:**
# - Динамика изменения расходов по месяцам и неделям показывает увеличение расходов на маркетинг по каналам привлечения TipTop и FaceBoom. Учитывая количество привлеченных пользователей с этих каналов, это может быть одной из причин низкой окупаемости в целом.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Немного не то, по заданию просили:
#
# * "Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) <b>по каждому источнику</b>. Постарайтесь отразить это на одном графике."

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Скорректировал код, вывел новый график, скорректировал выводы. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Всё здорово, теперь все в соответствии с заданием

# %% [markdown]
# #### Средняя стоимость привлечения пользователя по каналам привлечения

# %%
(profiles.pivot_table(index='channel', values='acquisition_cost', aggfunc='mean')
         .sort_values(by='acquisition_cost', ascending=False)
)
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172
# organic                     0.000000

# %%
# найдем среднюю стоимость привлечения пользователя
profiles['acquisition_cost'].mean()
# Out:
# 0.7032778251826568

# %% [markdown]
# **Основные выводы:**
# - Самая высокая стоимость привлечения пользователя на канале TipTop, возможно поэтому этот канал имеет 2-ое по величине количество привлеченных пользователей (после Faceboom), однако это не повлияло на число платящих среди них.
# - Вторым по средней стоимости привлечения расположился канал FaceBoom, занимающий первое место (после organic) по количеству привлеченных пользователей и первое место по доле платящих среди них.
# - Каналы AdNonSense и lambdaMediaAds по стоимости привлечения пользователей расположились на 3 и 4 местах соответственно. Помня о доле платящих клиентов этих каналов привлечения (>10%), можно сказать, что эти каналы являются интересными с точки зрения потенциальной прибыли, но так ли это узнаем уже в конце анализа.
# - Учитывая средний показатель стоимости привлечения пользователя, стоимость привлечения через канал TipTop выглядит достаточно дорогой.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> САС по всем каналам определен и проанализирован очень детально</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Еще хорошо было бы добавить расчет среднего САС для всего проекта

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Добавил расчет среднего CAC, дополнил вывод (последний пункт). </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Отлично!

# %% [markdown]
# ### Оцените окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %% [markdown]
# #### Общая окупаемость рекламы

# %% [markdown]
# Выберем моментом анализа 1 ноября 2019 года, горизонтом анализа определим период в 14 дней.
# Здесь и далее при анализе (кроме расчета общей конверсии и общего удержания пользователей) не будем учитывать пользователей, пришедших в приложение самостоятельно, во избежание искажения данных.

# %%
observation_date = datetime(2019,11,1).date()
analysis_horizon = 14

# %%
ltv_grouped, ltv, ltv_history, roi, roi_history = get_ltv(profiles.query('channel != "organic"'), orders, observation_date, analysis_horizon)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Все необходимые фильтры установлены</div>

# %% [markdown]
# Проверим работу функции и вывведем таблицы ltv и roi по всем пользователям на экран:

# %%
ltv
# Out:
#            cohort_size      0.0       1.0       2.0      3.0       4.0  \
# cohort
# All users        88644  0.34558  0.435754  0.504507  0.56109  0.611436
#
#                 5.0      6.0       7.0       8.0       9.0      10.0     11.0  \
# cohort
# All users  0.654368  0.69414  0.729778  0.764619  0.796665  0.826152  0.85207
#
#                12.0     13.0
# cohort
# All users  0.878116  0.90203

# %%
roi
# Out:
#            cohort_size       cac       0.0       1.0       2.0       3.0  \
# cohort
# All users        88644  1.117794  0.309163  0.389834  0.451341  0.501962
#
#                 4.0      5.0       6.0       7.0       8.0       9.0  \
# cohort
# All users  0.547002  0.58541  0.620991  0.652873  0.684043  0.712711
#
#                10.0      11.0      12.0      13.0
# cohort
# All users  0.739091  0.762278  0.785579  0.806974

# %% [markdown]
# Построим графики LTV и ROI, а также графики динамики LTV, ROI и CAC по всем пользователем в заданном временном интервале:

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, analysis_horizon)

# %% [markdown]
# **Основные выводы:**
# - На конец 2-ой недели реклама не окупилась: ROI на 14 день около 80%
# - Средняя стоимость привлечения пользователей выросла почти в 2 раза за 6 месяцев, возможно, это одна из причин снижения ROI на последнем графике: резкое увеличение стоимости привлечения в конце мая 2019 совпадает с резким снижением ROI в тот же период
# - LTV достаточно стабилен: колебания в интервале 0.8 - 1

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Здорово, все коротко и ясно</div>

# %% [markdown]
# #### Конверсия и удержание пользователей
#
# Посмотрим на график конверсии пользователей за 14 дней и график динамики конверсии на конец 2-ой недели:

# %%
conversion_grouped, conversion, conversion_history = get_conversion(profiles, orders, observation_date, analysis_horizon)

plot_conversion(conversion, conversion_history, analysis_horizon, window=14)

# %% [markdown]
# **Основные выводы:**
# - Конверсия пользователей, привлеченных начиная с июня 2019 года, стала более 50%, что, конечно, хорошо. Однако в последующие месяцы конверсия не поднималась выше 65% и окупаемость рекламы в этот период упала.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Еще неплохо было бы отметить некоторую сезонность у конверсии)</div>

# %% [markdown]
# Посмотрим на график удержания пользователей за 14 дней и график динамики удержания на конец 2-ой недели:

# %%
retention_raw, retention, retention_history = get_retention(profiles, visits, observation_date, analysis_horizon)

plot_retention(retention, retention_history, analysis_horizon, window=14)

# %% [markdown]
# На конец 2-ой недели среднее удержание платящих пользователей около 13% - нужно рассмотреть конверсии пользователей в разрезе регионов, устройств и каналов привлечения.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Хорошо, что не забыл про конверсию, действительно посмотрев на анализ в разрезе сегментов можно сделать больше выводов</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Органику достаточно удалить один раз, чтобы не было необходимости делать этого каждый раз)

# %%
# построим графики удержания и динамики удержания в разбивке по устройствам
retention_raw, retention, retention_history = get_retention(
        profiles.query('channel != "organic"'), 
        visits, 
        observation_date, 
        analysis_horizon,
        dimensions=['device']
)
plot_retention(retention, retention_history, analysis_horizon, window=14)

# %% [markdown]
# В разбивке пользователей по устройствам видим схожие показатели удержания и динамики удержания неплатящих пользователей по всем устройствам. Для платящих пользователей удержание на устройствах PC чуть выше остальных, но в целом явных отклонений нет.
#
# Посмотрим на удержание по регионам:

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> В целом и правда его можно назвать достаточно стабильным</div>

# %%
# построим графики удержания и динамики удержания в разбивке по регионам
retention_raw, retention, retention_history = get_retention(
        profiles.query('channel != "organic"'), 
        visits, 
        observation_date, 
        analysis_horizon,
        dimensions=['region']
)
plot_retention(retention, retention_history, analysis_horizon, window=14)

# %% [markdown]
# На графиках удержания пользователей по регионам видим низкие показатели удержания в США, динамика на 14-ый день также показывает стабильно низкое удержание пользователей из США на уровне 10%, в то время как количество зарегистрированных пользователей в США наибольшее количество.
#
# Посмотрим также на удержание пользователей по каналам привлечения (исключив органический трафик из анализа):

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> США достаточно сильно выделяется на фоне других каналов</div>

# %%
# построим графики удержания и динамики удержания в разбивке по каналам привлечения пользователей
retention_raw, retention, retention_history = get_retention(
        profiles.query('channel != "organic"'), 
        visits, 
        observation_date, 
        analysis_horizon,
        dimensions=['channel']
)

plot_retention(retention, retention_history, analysis_horizon, window=7)

# %% [markdown]
# **Основные выводы:**
# - На графике удержания платящих пользователей видим низкие показатели удержания для каналов AdNonSense и FaceBoom, возможно пользователи, привлеченные по этим рекламным каналам, заходили в приложение целенаправленно совершить какие-либо покупки, после чего практически не заходили в приложение.
# - По графику динамики удержания пользователей на конец 2-ой сложно сделать определенные выводы, но явно прослеживается практически стабильное удержание пользователей с канала TipTop и стабильно низкое удержание пользователей с канала FaceBoom, также по отдельным значениям на графике можно сказать и о низких значениях удержания пользователей с канала AdNonSense.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Тут также безусловно несколько каналов заметны выделяются на фоне других, кажется это одни из главных виновников провала рекламной кампании</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Еще неплохо было бы проанализировать таким же образом и конверсию для каналов)

# %% [markdown]
# #### Окупаемость рекламы с разбивкой по устройствам
#
# Построим графики LTV, ROI и CAC с разбивкой по устройствам:

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles, orders, observation_date, analysis_horizon, dimensions=['device']
)

plot_ltv_roi(ltv, ltv_history, roi, roi_history, analysis_horizon, window=14)

# %% [markdown]
# **Основные выводы:**
# - Видим, что процент окупаемости расположился пропорционально изменениям в затратах на привлечение пользователей: стоимость привлечения пользователей на Iphone и Mac увеличилась больше, чем для устройств Android и PC, в то время как на конец второй недели реклама для пользователей на устройствах PC и Android окупилась, а вот для яблочных устройств нет (возврат на ивестиции равен 90%).

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> В полной мере успешной можно назвать разве что кампанию по ПК</div>

# %% [markdown]
# #### Окупаемость рекламы с разбивкой по странам
#
# Построим графики LTV, ROI и CAC с разбивкой по странам (в анализе не будем учитывать пользователей, пришедших в приложение самостоятельно):

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, analysis_horizon, dimensions=['region']
)

plot_ltv_roi(ltv, ltv_history, roi, roi_history, analysis_horizon, window=14)

# %% [markdown]
# **Основные выводы:**
# - Пожизненная ценность пользователей США в течении анализируемого периода выше ценности пользователей из других стран, но вот похоже затраты на их привлечение сильно повлияли на окупаемость рекламы: стоимость затрат на привлечение пользователей в США начиная с июня по ноябрь выросла более чем в 2 раза (при достаточно стабильном LTV), что не могло не отразиться на ROI и его динамике на конец 2-ой недели.
# - Затраты на рекламу во всех странах, кроме США, полностью окупились

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> И США при анализе основных бизнес-показателей также показывает себя не самым лучшим образом</div>

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, analysis_horizon, dimensions=['channel']
)

plot_ltv_roi(ltv, ltv_history, roi, roi_history, analysis_horizon, window=14)

# %% [markdown]
# **Основные выводы:**
# - Канал TipTop показывает стабильно высокий LTV пользователей, однако увеличение стоимости привлечения пользователей в 3,5 раза привело к падению динамики ROI. Если учесть, что в рассматриваемый период по этому рекламному каналу было привлечено около 13% пользователей, компания потерпела большие убытки.
# - Каналы AdNonSense и FaceBoom также не оправдали ожиданий: после канала TipTop они занимают 2 и 3 место по стоимости привлечения и оба не окупились
# - Хороший LTV и динамику LTV показывает канала lambaMediaAds: имея не самую высокую стоимость привлечения и большой процент платящих пользователей канал находится в первой тройке лидеров по окупаемости и достатовчно высокие показатели динамики ROI на конец 2-недели
# - В лидеры по окупаемости вырвались каналы YRabbit и MediaTornado: процент платящих пользователей среди всех привлеченных в этих каналах один из самых низких, однако учитывая стоимость привлечения пользователя эти каналы показали лучшие результаты по окупаемости и динамике окупаемости на конец 2 недели.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Очень подробно и по пунктам описал также все рекламные каналы</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Еще исходя из таких проблем США хорошо было бы добавить анализ основных бизнес-показателей каналов и устройств в разрезе США-неСША

# %% [markdown]
# #### Ответы на вопросы:
#
# **Окупается ли реклама, направленная на привлечение пользователей в целом?**
# - В целом реклама на конец 2-ой недели согласно бизнес-плана не окупается.
#
# **Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?**
# - В ходе анализа мы выяснили, что с июня почти в 3,5 раза возросли затраты на привлечения пользователей через канал TipTop. Учитывая большое количество привлеченных пользователей (около 13%) и стабильный уроввень LTV, этот канал не окупился и более того показал наихудшие показатели окупаемости, что повлияло и на окупаемость затрат в целом. Также негативное влияние оказал канал FaceBoom с наибольшим количеством привлеченных пользователей и высокой стоимостью привлечения: инвестиции в канал также не окупились и принесли компании только убытки.
# - Также следует отметить, что несмотря на высокую "пожизненную ценность" пользователей США, количество которых является самым наибольшим в предоставленных данных, расходы на их привлечение в разы превышают расходы на привлечение пользователей из других стран, что снижает окупаемость вложений.
#
# **Чем могут быть вызваны проблемы окупаемости?**
# - По моему мнению, проблемы окупаемости могут быть вызваны нерациональным распределением расходов. Считаю, что анализ бизнес-показателей нужно проводить регулярно (к примеру, ежемесячно) и на основании полученных результатов переоценивать и перераспределять расходы в направлении потенциально прибыльных каналов привлечения, а также расширять географию бизнеса. Возможно, проводя анализ регулярнее компания могла раньше оценить прибыльность тех или иных каналов привлечения и перестроить свой бюджет.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Совершенно верно! Без замечаний по всем ответам, молодец</div>

# %% [markdown]
# ### Напишите выводы
#
# - Выделите причины неэффективности привлечения пользователей.
# - Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# **ОБЩИЕ ВЫВОДЫ**
#
# На основании проведенного анализа получили следующие результаты:
# - Наибольшее количество зарегистрированных пользователей из США, наибольший процент платящих пользователей среди представленных стран также  в США, однако, как показал график динамики затрат на привлечение пользователей, пользователи из США обходятся компании дороже всего при стабильном LTV на конец 2-ой недели. Это одна из причин, по которой рекламная кампания не достигла окупаемости в этой стране. Скорее всего каналы привлечения работают в основном на привлечение пользователей из США и, возможно, требуется пересмотреть географию бизнеса или сделать упор на другие страны, где затраты на маркетинг окупаются.
#
# - Изначально мы вычислили рекламные каналы, которые проносят компании больше всего клиентов и определили процент платящих среди них. В фавориты по количеству привлеченных пользователей попали такие каналы, как: FaceBoom и TipTop; по проценту платящих среди пользователей в фавориты попали: FaceBoom, TipTop, AdNonSense и lambdaMediaAds: аутсайдерами оказались каналы привлечения MediaTornado и YRabbit. После проведенного анализа мы увидели другую картину: MediaTornado, YRabbit и lambdaMediaAds вышли на окупаемость более 200%, в то время как каналы, принесшие компании в общей сложности около 1/3 всех пользователей даже не достигли порога окупаемости. Также стоит отметить, что стоимость привлечения пользователей, пришедших через канал TipTop, выросла в 3,5 раза за наблюдаемый период, а средний LTV за весь период был на одном уровне, т.е. ценность пользователя на конец каждой 2-ой недели не росла, а убытки на привлечение возрастали, что и привело к самому низкому показателю окупаемости около 50%. Канал FaceBoom также не оправдал ожиданий: при стабильном среднем LTV и высокой стоимости привлечения он не вышел на должный уровень окупаемости. Канал AdNonSense, хоть и подавал небольшие надежды на возможную прибыль в связи с высоким процентом платящих пользователей, также не вышел на окупаемость. Из всего вышесказанного следует, что не всегда высокие показатели количества привлеченных и доли платящих клиентов у рекламных каналов говорят о их прибыльности. В случае нашей компании, стоит пересмотреть траты на каналы привлечения, уменьшить траты на рекламу в каналах TipTop и FaceBoom и направить на рекламу в других каналах, показывающих большую окупаемость.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Замечательно! Ты сформулировал понятные выводу по проекту и логичные рекомендации

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Рекомендации:
#
# По сути своей весь анализ в этом спринте в той или иной мере основан на когортном анализе, прикреплю полезные ссылки на него. Но на самом деле очень советую в целом полистать gopractice, там очень хорошо описаны все бизнесовые и продуктовые метрики, этот курс часто приводят в пример для продуктовых аналитиков.
#
# https://blog.ohmystats.com/cohort-analysis/
#
# https://gopractice.ru/cohort_analysis/
#
# https://smysl.io/blog/pandas-cohorts/</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Кирилл, проект отличный! У тебя очень сильные аналитические навыки, владение инструментами для проведения исследования и навыки продуктовой аналитики. Но всё же в проекте есть буквально одно критическое замечание и я попрошу тебя исправить его, чтобы проект стал еще лучше! </div>
